# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#10-Minutes-to-pandas" data-toc-modified-id="10-Minutes-to-pandas-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>10 Minutes to pandas</a></span><ul class="toc-item"><li><span><a href="#Object-Creation" data-toc-modified-id="Object-Creation-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Object Creation</a></span></li><li><span><a href="#Viewing-Data" data-toc-modified-id="Viewing-Data-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Viewing Data</a></span></li><li><span><a href="#Selection" data-toc-modified-id="Selection-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Selection</a></span><ul class="toc-item"><li><span><a href="#Getting" data-toc-modified-id="Getting-1.3.1"><span class="toc-item-num">1.3.1&nbsp;&nbsp;</span>Getting</a></span></li><li><span><a href="#Selection-by-Label" data-toc-modified-id="Selection-by-Label-1.3.2"><span class="toc-item-num">1.3.2&nbsp;&nbsp;</span>Selection by Label</a></span></li><li><span><a href="#Selection-by-Position" data-toc-modified-id="Selection-by-Position-1.3.3"><span class="toc-item-num">1.3.3&nbsp;&nbsp;</span>Selection by Position</a></span></li></ul></li><li><span><a href="#Boolean-Indexing" data-toc-modified-id="Boolean-Indexing-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Boolean Indexing</a></span></li><li><span><a href="#Setting" data-toc-modified-id="Setting-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Setting</a></span></li><li><span><a href="#Missing-Data" data-toc-modified-id="Missing-Data-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>Missing Data</a></span></li><li><span><a href="#Operations" data-toc-modified-id="Operations-1.7"><span class="toc-item-num">1.7&nbsp;&nbsp;</span>Operations</a></span><ul class="toc-item"><li><span><a href="#Stats" data-toc-modified-id="Stats-1.7.1"><span class="toc-item-num">1.7.1&nbsp;&nbsp;</span>Stats</a></span></li><li><span><a href="#Apply" data-toc-modified-id="Apply-1.7.2"><span class="toc-item-num">1.7.2&nbsp;&nbsp;</span>Apply</a></span></li><li><span><a href="#Histogramming" data-toc-modified-id="Histogramming-1.7.3"><span class="toc-item-num">1.7.3&nbsp;&nbsp;</span>Histogramming</a></span></li><li><span><a href="#String-Methods" data-toc-modified-id="String-Methods-1.7.4"><span class="toc-item-num">1.7.4&nbsp;&nbsp;</span>String Methods</a></span></li></ul></li><li><span><a href="#Merge" data-toc-modified-id="Merge-1.8"><span class="toc-item-num">1.8&nbsp;&nbsp;</span>Merge</a></span><ul class="toc-item"><li><span><a href="#Concat" data-toc-modified-id="Concat-1.8.1"><span class="toc-item-num">1.8.1&nbsp;&nbsp;</span>Concat</a></span></li><li><span><a href="#Join" data-toc-modified-id="Join-1.8.2"><span class="toc-item-num">1.8.2&nbsp;&nbsp;</span>Join</a></span></li><li><span><a href="#Append" data-toc-modified-id="Append-1.8.3"><span class="toc-item-num">1.8.3&nbsp;&nbsp;</span>Append</a></span></li></ul></li><li><span><a href="#Grouping" data-toc-modified-id="Grouping-1.9"><span class="toc-item-num">1.9&nbsp;&nbsp;</span>Grouping</a></span></li><li><span><a href="#Reshaping" data-toc-modified-id="Reshaping-1.10"><span class="toc-item-num">1.10&nbsp;&nbsp;</span>Reshaping</a></span><ul class="toc-item"><li><span><a href="#Stack" data-toc-modified-id="Stack-1.10.1"><span class="toc-item-num">1.10.1&nbsp;&nbsp;</span>Stack</a></span></li><li><span><a href="#Pivot-Tables" data-toc-modified-id="Pivot-Tables-1.10.2"><span class="toc-item-num">1.10.2&nbsp;&nbsp;</span>Pivot Tables</a></span></li></ul></li><li><span><a href="#Time-Series" data-toc-modified-id="Time-Series-1.11"><span class="toc-item-num">1.11&nbsp;&nbsp;</span>Time Series</a></span></li><li><span><a href="#Categoricals" data-toc-modified-id="Categoricals-1.12"><span class="toc-item-num">1.12&nbsp;&nbsp;</span>Categoricals</a></span></li><li><span><a href="#Plotting" data-toc-modified-id="Plotting-1.13"><span class="toc-item-num">1.13&nbsp;&nbsp;</span>Plotting</a></span></li><li><span><a href="#Getting-Data-In/Out" data-toc-modified-id="Getting-Data-In/Out-1.14"><span class="toc-item-num">1.14&nbsp;&nbsp;</span>Getting Data In/Out</a></span><ul class="toc-item"><li><span><a href="#CSV" data-toc-modified-id="CSV-1.14.1"><span class="toc-item-num">1.14.1&nbsp;&nbsp;</span>CSV</a></span></li><li><span><a href="#HDF5" data-toc-modified-id="HDF5-1.14.2"><span class="toc-item-num">1.14.2&nbsp;&nbsp;</span>HDF5</a></span></li><li><span><a href="#Excel" data-toc-modified-id="Excel-1.14.3"><span class="toc-item-num">1.14.3&nbsp;&nbsp;</span>Excel</a></span></li><li><span><a href="#Gotchas" data-toc-modified-id="Gotchas-1.14.4"><span class="toc-item-num">1.14.4&nbsp;&nbsp;</span>Gotchas</a></span></li></ul></li><li><span><a href="#Play-with-SQlite-DB" data-toc-modified-id="Play-with-SQlite-DB-1.15"><span class="toc-item-num">1.15&nbsp;&nbsp;</span>Play with SQlite DB</a></span><ul class="toc-item"><li><span><a href="#Answer-the-Project-2-Query-questions" data-toc-modified-id="Answer-the-Project-2-Query-questions-1.15.1"><span class="toc-item-num">1.15.1&nbsp;&nbsp;</span>Answer the Project 2 Query questions</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# http://pandas.pydata.org/pandas-docs/stable/10min.html

# %% [markdown]
# # 10 Minutes to pandas
#
# This is a short introduction to pandas, geared mainly for new users. You can see more complex recipes in the [Cookbook](http://pandas.pydata.org/pandas-docs/stable/cookbook.html#cookbook)

# %% [markdown]
# Customarily, we import as follows:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# /Users/chengnie/anaconda3/envs/py35/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /Users/chengnie/anaconda3/envs/py35/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
# %matplotlib inline

# %% [markdown]
# ## Object Creation
#
# See the [Data Structure Intro section](http://pandas.pydata.org/pandas-docs/stable/dsintro.html#dsintro)

# %% [markdown]
# Creating a Series by passing a list of values, letting pandas create a default integer index:

# %%
s = pd.Series([1,3,5,np.nan,6,8])

# %%
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %% [markdown]
# Creating a DataFrame by passing a numpy array, with a datetime index and labeled columns:

# %%
dates = pd.date_range('20130101', periods=6)

# %%
dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(6,4), index=dates, columns=list('ABCD'))

# %%
df
# Out:
#                    A         B         C         D
# 2013-01-01  0.228834  0.828922  0.076657 -0.429588
# 2013-01-02 -1.318216 -0.712206  0.221339 -0.833141
# 2013-01-03  0.439934 -1.188770  0.397939 -0.934707
# 2013-01-04  0.788358 -0.599466 -0.340757 -1.112828
# 2013-01-05 -0.244217  0.702103 -0.157185 -0.025745
# 2013-01-06 -1.821725 -0.091525 -0.446694 -0.069316

# %% [markdown]
# Creating a DataFrame by passing a dict of objects that can be converted to series-like.

# %%
df2 = pd.DataFrame({'A':1.,
                   'B':pd.Timestamp('20130102'),
                   'C':pd.Series(1,index=list(range(4)),dtype='float32'),
                   'D':np.array([3]*4,dtype='int32'),
                   'E':pd.Categorical(["test","train","test","train"]),
                   'F':'foo'})

# %%
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %% [markdown]
# Having specific [dtypes](http://pandas.pydata.org/pandas-docs/stable/basics.html#basics-dtypes)

# %%
df2.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %% [markdown]
# If you’re using IPython, tab completion for column names (as well as public attributes) is automatically enabled. Here’s a subset of the attributes that will be completed:

# %%
# df2.<TAB>

# %% [markdown]
# As you can see, the columns A, B, C, and D are automatically tab completed. E is there as well; the rest of the attributes have been truncated for brevity.

# %% [markdown]
# ## Viewing Data
#
# See the [Basics section](http://pandas.pydata.org/pandas-docs/stable/basics.html#basics)

# %% [markdown]
# See the top & bottom rows of the frame

# %%
df.head()
# Out:
#                    A         B         C         D
# 2013-01-01  1.571507  0.160021 -0.015071 -0.118588
# 2013-01-02 -1.037697 -0.891196  0.495447  0.453095
# 2013-01-03 -1.682384 -0.026006 -0.152957 -0.212614
# 2013-01-04 -0.108757 -0.958267  0.407331  0.187037
# 2013-01-05  1.092380  2.841777 -0.125714 -0.760722

# %%
df.tail(3)
# Out:
#                    A         B         C         D
# 2013-01-04 -0.108757 -0.958267  0.407331  0.187037
# 2013-01-05  1.092380  2.841777 -0.125714 -0.760722
# 2013-01-06  1.638509 -0.601126 -1.043931 -1.330950

# %% [markdown]
# Display the index, columns, and the underlying numpy data

# %%
df.index
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.columns
# Out:
# Index([u'A', u'B', u'C', u'D'], dtype='object')

# %%
df.values
# Out:
# array([[ 1.57150668,  0.16002149, -0.01507058, -0.11858772],
#        [-1.03769719, -0.89119559,  0.49544709,  0.45309462],
#        [-1.68238391, -0.02600566, -0.15295699, -0.21261369],
#        [-0.10875693, -0.9582675 ,  0.40733062,  0.18703669],
#        [ 1.09238026,  2.84177746, -0.12571427, -0.76072186],
#        [ 1.63850927, -0.60112596, -1.04393119, -1.33095031]])

# %% [markdown]
# Describe shows a quick statistic summary of your data

# %%
df.describe()
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean   0.245593  0.087534 -0.072483 -0.297124
# std    1.407466  1.423367  0.549378  0.651149
# min   -1.682384 -0.958267 -1.043931 -1.330950
# 25%   -0.805462 -0.818678 -0.146146 -0.623695
# 50%    0.491812 -0.313566 -0.070392 -0.165601
# 75%    1.451725  0.113515  0.301730  0.110631
# max    1.638509  2.841777  0.495447  0.453095

# %% [markdown]
# Transposing your data

# %%
df.T
# Out:
#    2013-01-01  2013-01-02  2013-01-03  2013-01-04  2013-01-05  2013-01-06
# A    1.571507   -1.037697   -1.682384   -0.108757    1.092380    1.638509
# B    0.160021   -0.891196   -0.026006   -0.958267    2.841777   -0.601126
# C   -0.015071    0.495447   -0.152957    0.407331   -0.125714   -1.043931
# D   -0.118588    0.453095   -0.212614    0.187037   -0.760722   -1.330950

# %% [markdown]
# Sorting by an axis

# %%
df.sort_index(axis=1, ascending=False)
# Out:
#                    D         C         B         A
# 2013-01-01 -0.118588 -0.015071  0.160021  1.571507
# 2013-01-02  0.453095  0.495447 -0.891196 -1.037697
# 2013-01-03 -0.212614 -0.152957 -0.026006 -1.682384
# 2013-01-04  0.187037  0.407331 -0.958267 -0.108757
# 2013-01-05 -0.760722 -0.125714  2.841777  1.092380
# 2013-01-06 -1.330950 -1.043931 -0.601126  1.638509

# %% [markdown]
# Sorting by value

# %%
df.sort_values(by='B')
# Out:
#                    A         B         C         D
# 2013-01-04 -0.108757 -0.958267  0.407331  0.187037
# 2013-01-02 -1.037697 -0.891196  0.495447  0.453095
# 2013-01-06  1.638509 -0.601126 -1.043931 -1.330950
# 2013-01-03 -1.682384 -0.026006 -0.152957 -0.212614
# 2013-01-01  1.571507  0.160021 -0.015071 -0.118588
# 2013-01-05  1.092380  2.841777 -0.125714 -0.760722

# %% [markdown]
# ## Selection

# %% [markdown]
# **Note:** While standard Python / Numpy expressions for selecting and setting are intuitive and come in handy for interactive work, for production code, we recommend the optimized pandas data access methods, .at, .iat, .loc, .iloc and .ix.

# %% [markdown]
# See the indexing documentation [Indexing and Selecting Data](http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing) and [MultiIndex / Advanced Indexing](http://pandas.pydata.org/pandas-docs/stable/advanced.html#advanced)

# %% [markdown]
# ### Getting

# %% [markdown]
# Selecting a single column, which yields a Series, equivalent to df.A

# %%
df['A']
# Out:
# 2013-01-01    1.571507
# 2013-01-02   -1.037697
# 2013-01-03   -1.682384
# 2013-01-04   -0.108757
# 2013-01-05    1.092380
# 2013-01-06    1.638509
# Freq: D, Name: A, dtype: float64

# %% [markdown]
# Selecting via [], which slices the rows.

# %%
df[0:3]
# Out:
#                    A         B         C         D
# 2013-01-01  1.571507  0.160021 -0.015071 -0.118588
# 2013-01-02 -1.037697 -0.891196  0.495447  0.453095
# 2013-01-03 -1.682384 -0.026006 -0.152957 -0.212614

# %%
df['20130102':'20130104']
# Out:
#                    A         B         C         D
# 2013-01-02 -1.037697 -0.891196  0.495447  0.453095
# 2013-01-03 -1.682384 -0.026006 -0.152957 -0.212614
# 2013-01-04 -0.108757 -0.958267  0.407331  0.187037

# %% [markdown]
# ### Selection by Label
#
# See more in [Selection by Label](Selection by Label)

# %% [markdown]
# For getting a cross section using a label

# %%
df.loc[dates[0]]
# Out:
# A    1.571507
# B    0.160021
# C   -0.015071
# D   -0.118588
# Name: 2013-01-01 00:00:00, dtype: float64

# %% [markdown]
# Selection by Label

# %%
df.loc[:,['A','B']]
# Out:
#                    A         B
# 2013-01-01  1.571507  0.160021
# 2013-01-02 -1.037697 -0.891196
# 2013-01-03 -1.682384 -0.026006
# 2013-01-04 -0.108757 -0.958267
# 2013-01-05  1.092380  2.841777
# 2013-01-06  1.638509 -0.601126

# %% [markdown]
# Showing label slicing, both endpoints are included

# %%
df.loc['20130102':'20130104',['A','B']]
# Out:
#                    A         B
# 2013-01-02 -1.037697 -0.891196
# 2013-01-03 -1.682384 -0.026006
# 2013-01-04 -0.108757 -0.958267

# %% [markdown]
# Reduction in the dimensions of the returned object

# %%
df.loc['20130102',['A','B']]
# Out:
# A   -1.037697
# B   -0.891196
# Name: 2013-01-02 00:00:00, dtype: float64

# %% [markdown]
# For getting a scalar value

# %%
df.loc[dates[0],'A']
# Out:
# 1.571506676720408

# %% [markdown]
# ### Selection by Position
#
# See more in [Selection by Position](http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-integer)

# %% [markdown]
# Select via the position of the passed integers

# %%
df.iloc[3]
# Out:
# A   -0.108757
# B   -0.958267
# C    0.407331
# D    0.187037
# Name: 2013-01-04 00:00:00, dtype: float64

# %% [markdown]
# By integer slices, acting similar to numpy/python

# %%
df.iloc[3:5,0:2]
# Out:
#                    A         B
# 2013-01-04 -0.108757 -0.958267
# 2013-01-05  1.092380  2.841777

# %% [markdown]
# By lists of integer position locations, similar to the numpy/python style

# %%
df.iloc[[1,2,4],[0,2]]
# Out:
#                    A         C
# 2013-01-02 -1.037697  0.495447
# 2013-01-03 -1.682384 -0.152957
# 2013-01-05  1.092380 -0.125714

# %% [markdown]
# For slicing rows explicitly

# %%
df.iloc[1:3,:]
# Out:
#                    A         B         C         D
# 2013-01-02 -1.037697 -0.891196  0.495447  0.453095
# 2013-01-03 -1.682384 -0.026006 -0.152957 -0.212614

# %% [markdown]
# For slicing columns explicitly

# %%
df.iloc[:,1:3]
# Out:
#                    B         C
# 2013-01-01  0.160021 -0.015071
# 2013-01-02 -0.891196  0.495447
# 2013-01-03 -0.026006 -0.152957
# 2013-01-04 -0.958267  0.407331
# 2013-01-05  2.841777 -0.125714
# 2013-01-06 -0.601126 -1.043931

# %% [markdown]
# For getting a value explicitly

# %%
df.iloc[1,1]
# Out:
# -0.89119558600132898

# %% [markdown]
# For getting fast access to a scalar (equiv to the prior method)

# %%
df.iat[1,1]
# Out:
# -0.89119558600132898

# %% [markdown]
# ## Boolean Indexing

# %% [markdown]
# Using a single column’s values to select data.

# %%
df[df.A > 0]
# Out:
#                    A         B         C         D
# 2013-01-01  1.571507  0.160021 -0.015071 -0.118588
# 2013-01-05  1.092380  2.841777 -0.125714 -0.760722
# 2013-01-06  1.638509 -0.601126 -1.043931 -1.330950

# %% [markdown]
# A where operation for getting.

# %%
df[df > 0]
# Out:
#                    A         B         C         D
# 2013-01-01  1.571507  0.160021       NaN       NaN
# 2013-01-02       NaN       NaN  0.495447  0.453095
# 2013-01-03       NaN       NaN       NaN       NaN
# 2013-01-04       NaN       NaN  0.407331  0.187037
# 2013-01-05  1.092380  2.841777       NaN       NaN
# 2013-01-06  1.638509       NaN       NaN       NaN

# %% [markdown]
# Using the isin() method for filtering:

# %%
df2 = df.copy()

# %%
df2['E'] = ['one','one', 'two','three','four','three']

# %%
df2
# Out:
#                    A         B         C         D      E
# 2013-01-01  1.571507  0.160021 -0.015071 -0.118588    one
# 2013-01-02 -1.037697 -0.891196  0.495447  0.453095    one
# 2013-01-03 -1.682384 -0.026006 -0.152957 -0.212614    two
# 2013-01-04 -0.108757 -0.958267  0.407331  0.187037  three
# 2013-01-05  1.092380  2.841777 -0.125714 -0.760722   four
# 2013-01-06  1.638509 -0.601126 -1.043931 -1.330950  three

# %%
df2[df2['E'].isin(['two','four'])]
# Out:
#                    A         B         C         D     E
# 2013-01-03 -1.682384 -0.026006 -0.152957 -0.212614   two
# 2013-01-05  1.092380  2.841777 -0.125714 -0.760722  four

# %% [markdown]
# ## Setting

# %% [markdown]
# Setting a new column automatically aligns the data by the indexes

# %%
s1 = pd.Series([1,2,3,4,5,6], index=pd.date_range('20130102',periods=6))

# %%
s1
# Out:
# 2013-01-02    1
# 2013-01-03    2
# 2013-01-04    3
# 2013-01-05    4
# 2013-01-06    5
# 2013-01-07    6
# Freq: D, dtype: int64

# %%
df['F'] = s1

# %% [markdown]
# Setting values by label

# %%
df.at[dates[0],'A'] = 0

# %% [markdown]
# Settomg values by position

# %%
df.iat[0,1] = 0

# %% [markdown]
# Setting by assigning with a numpy array

# %%
df.loc[:,'D'] = np.array([5] * len(df))

# %% [markdown]
# The result of the prior setting operations

# %%
df
# Out:
#                    A         B         C  D    F
# 2013-01-01  0.000000  0.000000 -0.015071  5  NaN
# 2013-01-02 -1.037697 -0.891196  0.495447  5  1.0
# 2013-01-03 -1.682384 -0.026006 -0.152957  5  2.0
# 2013-01-04 -0.108757 -0.958267  0.407331  5  3.0
# 2013-01-05  1.092380  2.841777 -0.125714  5  4.0
# 2013-01-06  1.638509 -0.601126 -1.043931  5  5.0

# %% [markdown]
# A where operation with setting.

# %%
df2 = df.copy()

# %%
df2[df2 > 0] = -df2

# %%
df2
# Out:
#                    A         B         C  D    F
# 2013-01-01  0.000000  0.000000 -0.015071 -5  NaN
# 2013-01-02 -1.037697 -0.891196 -0.495447 -5 -1.0
# 2013-01-03 -1.682384 -0.026006 -0.152957 -5 -2.0
# 2013-01-04 -0.108757 -0.958267 -0.407331 -5 -3.0
# 2013-01-05 -1.092380 -2.841777 -0.125714 -5 -4.0
# 2013-01-06 -1.638509 -0.601126 -1.043931 -5 -5.0

# %% [markdown]
# ## Missing Data
#
# pandas primarily uses the value np.nan to represent missing data. It is by default not included in computations. See the Missing Data section

# %% [markdown]
# Reindexing allows you to change/add/delete the index on a specified axis. This returns a copy of the data.

# %%
df1 = df.reindex(index=dates[0:4], columns=list(df.columns) + ['E'])

# %%
df1.loc[dates[0]:dates[1],'E'] = 1

# %%
df1
# Out:
#                    A         B         C  D    F    E
# 2013-01-01  0.000000  0.000000 -0.015071  5  NaN  1.0
# 2013-01-02 -1.037697 -0.891196  0.495447  5  1.0  1.0
# 2013-01-03 -1.682384 -0.026006 -0.152957  5  2.0  NaN
# 2013-01-04 -0.108757 -0.958267  0.407331  5  3.0  NaN

# %% [markdown]
# To drop any rows that have missing data.

# %%
df1.dropna(how='any')
# Out:
#                    A         B         C  D    F    E
# 2013-01-02 -1.037697 -0.891196  0.495447  5  1.0  1.0

# %% [markdown]
# Filling missing data

# %%
df1.fillna(value=5)
# Out:
#                    A         B         C  D    F    E
# 2013-01-01  0.000000  0.000000 -0.015071  5  5.0  1.0
# 2013-01-02 -1.037697 -0.891196  0.495447  5  1.0  1.0
# 2013-01-03 -1.682384 -0.026006 -0.152957  5  2.0  5.0
# 2013-01-04 -0.108757 -0.958267  0.407331  5  3.0  5.0

# %% [markdown]
# To get the boolean mask where values are nan

# %%
pd.isnull(df1)
# Out:
#                 A      B      C      D      F      E
# 2013-01-01  False  False  False  False   True  False
# 2013-01-02  False  False  False  False  False  False
# 2013-01-03  False  False  False  False  False   True
# 2013-01-04  False  False  False  False  False   True

# %% [markdown]
# ## Operations
#
# See the [Basic section on Binary Ops](http://pandas.pydata.org/pandas-docs/stable/basics.html#basics-binop)

# %% [markdown]
# ### Stats
#
# Operations in general exclude missing data.

# %% [markdown]
# Performing a descriptive statistic

# %%
df.mean()
# Out:
# A   -0.016325
# B    0.060864
# C   -0.072483
# D    5.000000
# F    3.000000
# dtype: float64

# %% [markdown]
# Same operation on the other axis

# %%
df.mean(1)
# Out:
# 2013-01-01    1.246232
# 2013-01-02    0.913311
# 2013-01-03    1.027731
# 2013-01-04    1.468061
# 2013-01-05    2.561689
# 2013-01-06    1.998690
# Freq: D, dtype: float64

# %% [markdown]
# Operating with objects that have different dimensionality and need alignment. In addition, pandas automatically broadcasts along the specified dimension.

# %%
s = pd.Series([1,3,5,np.nan,6,8], index=dates).shift(2)

# %%
s
# Out:
# 2013-01-01    NaN
# 2013-01-02    NaN
# 2013-01-03    1.0
# 2013-01-04    3.0
# 2013-01-05    5.0
# 2013-01-06    NaN
# Freq: D, dtype: float64

# %%
df.sub(s, axis='index')
# Out:
#                    A         B         C    D    F
# 2013-01-01       NaN       NaN       NaN  NaN  NaN
# 2013-01-02       NaN       NaN       NaN  NaN  NaN
# 2013-01-03 -2.682384 -1.026006 -1.152957  4.0  1.0
# 2013-01-04 -3.108757 -3.958267 -2.592669  2.0  0.0
# 2013-01-05 -3.907620 -2.158223 -5.125714  0.0 -1.0
# 2013-01-06       NaN       NaN       NaN  NaN  NaN

# %% [markdown]
# ### Apply

# %% [markdown]
# Applying functions to the data

# %%
df.apply(np.cumsum)
# Out:
#                    A         B         C   D     F
# 2013-01-01  0.000000  0.000000 -0.015071   5   NaN
# 2013-01-02 -1.037697 -0.891196  0.480377  10   1.0
# 2013-01-03 -2.720081 -0.917201  0.327420  15   3.0
# 2013-01-04 -2.828838 -1.875469  0.734750  20   6.0
# 2013-01-05 -1.736458  0.966309  0.609036  25  10.0
# 2013-01-06 -0.097949  0.365183 -0.434895  30  15.0

# %%
df.apply(lambda x: x.max() - x.min())
# Out:
# A    3.320893
# B    3.800045
# C    1.539378
# D    0.000000
# F    4.000000
# dtype: float64

# %% [markdown]
# ### Histogramming
#
# See more at [Histogramming and Discretization](http://pandas.pydata.org/pandas-docs/stable/basics.html#basics-discretization)

# %%
s = pd.Series(np.random.randint(0, 7, size=10))

# %%
s
# Out:
# 0    0
# 1    4
# 2    1
# 3    5
# 4    1
# 5    2
# 6    1
# 7    6
# 8    2
# 9    4
# dtype: int64

# %%
s.value_counts()
# Out:
# 1    3
# 4    2
# 2    2
# 6    1
# 5    1
# 0    1
# dtype: int64

# %% [markdown]
# ### String Methods
#
# Series is equipped with a set of string processing methods in the str attribute that make it easy to operate on each element of the array, as in the code snippet below. Note that pattern-matching in str generally uses [regular expressions](https://docs.python.org/2/library/re.html) by default (and in some cases always uses them). See more at [Vectorized String Methods](http://pandas.pydata.org/pandas-docs/stable/text.html#text-string-methods).

# %%
s = pd.Series(['A', 'B', 'C', 'Aaba', 'Baca', np.nan, 'CABA', 'dog', 'cat'])

# %%
s.str.lower()
# Out:
# 0       a
# 1       b
# 2       c
# 3    aaba
# 4    baca
# 5     NaN
# 6    caba
# 7     dog
# 8     cat
# dtype: object

# %% [markdown]
# ## Merge

# %% [markdown]
# ### Concat
#
# pandas provides various facilities for easily combining together Series, DataFrame, and Panel objects with various kinds of set logic for the indexes and relational algebra functionality in the case of join / merge-type operations.
#
# See the [Merging section](http://pandas.pydata.org/pandas-docs/stable/merging.html#merging)

# %% [markdown]
# Concatenating pandas objects together with concat():

# %%
df = pd.DataFrame(np.random.randn(10, 4))

# %%
df
# Out:
#           0         1         2         3
# 0 -0.478688 -1.065907 -0.813218  0.096970
# 1  0.414418 -0.364717 -0.515997  1.658804
# 2  0.596550 -0.336011  0.080922  0.524613
# 3  0.896945  0.584915  2.178190 -0.102500
# 4 -1.310291  0.680342  0.322909  0.319864
# 5  0.924658  0.485691 -0.105201 -0.438313
# 6 -1.515372 -0.275894  0.200431 -0.342667
# 7  1.259821  1.387931 -1.520080  0.236932
# 8  0.625367  1.485963 -0.075421 -1.865674
# 9 -1.015742 -0.935150 -1.148272 -1.007878

# %%
# break it into pieces
pieces = [df[:3], df[3:7], df[7:]]

# %%
pd.concat(pieces)
# Out:
#           0         1         2         3
# 0 -0.478688 -1.065907 -0.813218  0.096970
# 1  0.414418 -0.364717 -0.515997  1.658804
# 2  0.596550 -0.336011  0.080922  0.524613
# 3  0.896945  0.584915  2.178190 -0.102500
# 4 -1.310291  0.680342  0.322909  0.319864
# 5  0.924658  0.485691 -0.105201 -0.438313
# 6 -1.515372 -0.275894  0.200431 -0.342667
# 7  1.259821  1.387931 -1.520080  0.236932
# 8  0.625367  1.485963 -0.075421 -1.865674
# 9 -1.015742 -0.935150 -1.148272 -1.007878

# %% [markdown]
# ### Join
#
# SQL style merges. See the [Database style joining](http://pandas.pydata.org/pandas-docs/stable/merging.html#merging-join)

# %%
left = pd.DataFrame({'key': ['foo', 'foo'], 'lval': [1, 2]})

# %%
right = pd.DataFrame({'key': ['foo', 'foo'], 'rval': [4, 5]})

# %%
left
# Out:
#    key  lval
# 0  foo     1
# 1  foo     2

# %%
right
# Out:
#    key  rval
# 0  foo     4
# 1  foo     5

# %%
pd.merge(left, right, on='key')
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  foo     1     5
# 2  foo     2     4
# 3  foo     2     5

# %% [markdown]
# ### Append
#
# Append rows to a dataframe. See the [Appending](http://pandas.pydata.org/pandas-docs/stable/merging.html#merging-concatenation)

# %%
df = pd.DataFrame(np.random.randn(8, 4), columns=['A','B','C','D'])

# %%
df
# Out:
#           A         B         C         D
# 0 -0.512297  0.206320  0.806578 -1.023023
# 1  0.667535  0.552143 -0.956896 -0.447428
# 2  1.365881  0.308602  0.710462 -0.475598
# 3  0.496544 -0.215146  0.678528 -0.222261
# 4 -0.646788  0.065329 -1.191621 -0.348686
# 5 -1.228013  0.866045 -0.555290  1.709495
# 6 -0.284006 -1.252317  0.994436  1.883158
# 7 -0.980527  1.249698  0.268433 -0.926866

# %%
s = df.iloc[3]

# %%
df.append(s, ignore_index=True)
# Out:
#           A         B         C         D
# 0 -0.512297  0.206320  0.806578 -1.023023
# 1  0.667535  0.552143 -0.956896 -0.447428
# 2  1.365881  0.308602  0.710462 -0.475598
# 3  0.496544 -0.215146  0.678528 -0.222261
# 4 -0.646788  0.065329 -1.191621 -0.348686
# 5 -1.228013  0.866045 -0.555290  1.709495
# 6 -0.284006 -1.252317  0.994436  1.883158
# 7 -0.980527  1.249698  0.268433 -0.926866
# 8  0.496544 -0.215146  0.678528 -0.222261

# %% [markdown]
# ## Grouping
#
# By “group by” we are referring to a process involving one or more of the following steps
#
# * **Splitting** the data into groups based on some criteria
# * **Applying** a function to each group independently
# * **Combining** the results into a data structure
#
# See the [Grouping section](http://pandas.pydata.org/pandas-docs/stable/groupby.html#groupby)

# %%
df = pd.DataFrame({'A' : ['foo', 'bar', 'foo', 'bar', 'foo', 'bar', 'foo', 'foo'],
                                    'B' : ['one', 'one', 'two', 'three','two', 'two', 'one', 'three'],
                                    'C' : np.random.randn(8),
                                     'D' : np.random.randn(8)})

# %%
df
# Out:
#      A      B         C         D
# 0  foo    one -0.511975  0.127436
# 1  bar    one  1.065510  0.648988
# 2  foo    two  1.363103  0.565078
# 3  bar  three  1.663853  0.672468
# 4  foo    two -1.500158 -1.056229
# 5  bar    two  0.289049 -0.736059
# 6  foo    one  0.738343  0.417824
# 7  foo  three  0.373007 -0.744985

# %% [markdown]
# Grouping and then applying a function sum to the resulting groups.

# %%
df.groupby('A').sum()
# Out:
#             C         D
# A
# bar  3.018412  0.585397
# foo  0.462319 -0.690875

# %%
df.groupby(['A','B']).sum()
# Out:
#                   C         D
# A   B
# bar one    1.065510  0.648988
#     three  1.663853  0.672468
#     two    0.289049 -0.736059
# foo one    0.226368  0.545260
#     three  0.373007 -0.744985
#     two   -0.137056 -0.491150

# %% [markdown]
# ## Reshaping
#
# See the sections on [Hierarchical Indexing](http://pandas.pydata.org/pandas-docs/stable/advanced.html#advanced-hierarchical) and [Reshaping](http://pandas.pydata.org/pandas-docs/stable/reshaping.html#reshaping-stacking).

# %% [markdown]
# ### Stack

# %%
tuples = list(zip(*[['bar', 'bar', 'baz', 'baz', 'foo', 'foo', 'qux', 'qux'],
                                ['one', 'two', 'one', 'two', 'one', 'two', 'one', 'two']]))

# %%
index = pd.MultiIndex.from_tuples(tuples, names=['first', 'second'])

# %%
df = pd.DataFrame(np.random.randn(8, 2), index=index, columns=['A', 'B'])

# %%
df2 = df[:4]

# %%
df2
# Out:
#                      A         B
# first second
# bar   one    -0.509132 -1.047747
#       two    -0.738164 -0.161886
# baz   one    -1.522663 -0.572879
#       two     2.650861 -0.248318

# %% [markdown]
# The stack() method “compresses” a level in the DataFrame’s columns.

# %%
stacked = df2.stack()

# %%
stacked
# Out:
# first  second
# bar    one     A   -0.509132
#                B   -1.047747
#        two     A   -0.738164
#                B   -0.161886
# baz    one     A   -1.522663
#                B   -0.572879
#        two     A    2.650861
#                B   -0.248318
# dtype: float64

# %% [markdown]
# With a “stacked” DataFrame or Series (having a MultiIndex as the index), the inverse operation of stack() is unstack(), which by default unstacks the **last level**:

# %%
stacked.unstack()
# Out:
#                      A         B
# first second
# bar   one    -0.509132 -1.047747
#       two    -0.738164 -0.161886
# baz   one    -1.522663 -0.572879
#       two     2.650861 -0.248318

# %%
stacked.unstack(1)
# Out:
# second        one       two
# first
# bar   A -0.509132 -0.738164
#       B -1.047747 -0.161886
# baz   A -1.522663  2.650861
#       B -0.572879 -0.248318

# %%
stacked.unstack(0)
# Out:
# first          bar       baz
# second
# one    A -0.509132 -1.522663
#        B -1.047747 -0.572879
# two    A -0.738164  2.650861
#        B -0.161886 -0.248318

# %% [markdown]
# ### Pivot Tables
#
# See the section on [Pivot Tables](http://pandas.pydata.org/pandas-docs/stable/reshaping.html#reshaping-pivot).

# %%
df = pd.DataFrame({'A' : ['one', 'one', 'two', 'three'] * 3,
                                    'B' : ['A', 'B', 'C'] * 4,
                                    'C' : ['foo', 'foo', 'foo', 'bar', 'bar', 'bar'] * 2,
                                    'D' : np.random.randn(12),
                                    'E' : np.random.randn(12)})

# %%
df
# Out:
#         A  B    C         D         E
# 0     one  A  foo  0.609099  0.860723
# 1     one  B  foo -0.565647 -0.529125
# 2     two  C  foo  0.405552 -0.469248
# 3   three  A  bar  0.486600 -0.434941
# 4     one  B  bar  0.357269  1.063793
# 5     one  C  bar  0.015696  2.033839
# 6     two  A  foo  0.143828  0.250495
# 7   three  B  foo -0.290815  1.228481
# 8     one  C  foo  2.717677  0.147774
# 9     one  A  bar -0.894453  0.370378
# 10    two  B  bar -0.891609  2.113584
# 11  three  C  bar  0.212073 -0.598682

# %% [markdown]
# We can produce pivot tables from this data very easily:

# %%
pd.pivot_table(df, values='D', index=['A', 'B'], columns=['C'])
# Out:
# C             bar       foo
# A     B
# one   A -0.894453  0.609099
#       B  0.357269 -0.565647
#       C  0.015696  2.717677
# three A  0.486600       NaN
#       B       NaN -0.290815
#       C  0.212073       NaN
# two   A       NaN  0.143828
#       B -0.891609       NaN
#       C       NaN  0.405552

# %% [markdown]
# ## Time Series
#
# pandas has simple, powerful, and efficient functionality for performing resampling operations during frequency conversion (e.g., converting secondly data into 5-minutely data). This is extremely common in, but not limited to, financial applications. See the [Time Series section](http://pandas.pydata.org/pandas-docs/stable/timeseries.html#timeseries)

# %%
rng = pd.date_range('1/1/2012', periods=100, freq='S')

# %%
ts = pd.Series(np.random.randint(0, 500, len(rng)), index=rng)

# %%
ts.resample('5Min').sum()
# Out:
# 2012-01-01    25031
# Freq: 5T, dtype: int64

# %% [markdown]
# Time zone representation

# %%
rng = pd.date_range('3/6/2012 00:00', periods=5, freq='D')

# %%
ts = pd.Series(np.random.randn(len(rng)), rng)

# %%
ts
# Out:
# 2012-03-06    1.306330
# 2012-03-07    0.217167
# 2012-03-08   -0.781594
# 2012-03-09   -1.642100
# 2012-03-10    0.332460
# Freq: D, dtype: float64

# %%
ts_utc = ts.tz_localize('UTC')

# %%
ts_utc
# Out:
# 2012-03-06 00:00:00+00:00    1.306330
# 2012-03-07 00:00:00+00:00    0.217167
# 2012-03-08 00:00:00+00:00   -0.781594
# 2012-03-09 00:00:00+00:00   -1.642100
# 2012-03-10 00:00:00+00:00    0.332460
# Freq: D, dtype: float64

# %% [markdown]
# Convert to another time zone

# %%
ts_utc.tz_convert('US/Eastern')
# Out:
# 2012-03-05 19:00:00-05:00    1.306330
# 2012-03-06 19:00:00-05:00    0.217167
# 2012-03-07 19:00:00-05:00   -0.781594
# 2012-03-08 19:00:00-05:00   -1.642100
# 2012-03-09 19:00:00-05:00    0.332460
# Freq: D, dtype: float64

# %% [markdown]
# Converting between time span representations

# %%
rng = pd.date_range('1/1/2012', periods=5, freq='M')

# %%
ts = pd.Series(np.random.randn(len(rng)), index=rng)

# %%
ts
# Out:
# 2012-01-31   -0.096878
# 2012-02-29   -1.470980
# 2012-03-31   -0.199913
# 2012-04-30   -0.145233
# 2012-05-31    1.051845
# Freq: M, dtype: float64

# %%
ps = ts.to_period()

# %%
ps
# Out:
# 2012-01   -0.096878
# 2012-02   -1.470980
# 2012-03   -0.199913
# 2012-04   -0.145233
# 2012-05    1.051845
# Freq: M, dtype: float64

# %%
ps.to_timestamp()
# Out:
# 2012-01-01   -0.096878
# 2012-02-01   -1.470980
# 2012-03-01   -0.199913
# 2012-04-01   -0.145233
# 2012-05-01    1.051845
# Freq: MS, dtype: float64

# %% [markdown]
# Converting between period and timestamp enables some convenient arithmetic functions to be used. In the following example, we convert a quarterly frequency with year ending in November to 9am of the end of the month following the quarter end:

# %%
prng = pd.period_range('1990Q1', '2000Q4', freq='Q-NOV')

# %%
ts = pd.Series(np.random.randn(len(prng)), prng)

# %%
ts.index = (prng.asfreq('M', 'e') + 1).asfreq('H', 's') + 9

# %%
ts.head()
# Out:
# 1990-03-01 09:00   -0.290171
# 1990-06-01 09:00    0.445195
# 1990-09-01 09:00    1.493887
# 1990-12-01 09:00    0.804911
# 1991-03-01 09:00   -0.101456
# Freq: H, dtype: float64

# %% [markdown]
# ## Categoricals

# %% [markdown]
# Since version 0.15, pandas can include categorical data in a DataFrame. For full docs, see the [categorical introduction](http://pandas.pydata.org/pandas-docs/stable/categorical.html#categorical) and the [API documentation](http://pandas.pydata.org/pandas-docs/stable/api.html#api-categorical).

# %%
df = pd.DataFrame({"id":[1,2,3,4,5,6], "raw_grade":['a', 'b', 'b', 'a', 'a', 'e']})

# %% [markdown]
# Convert the raw grades to a categorical data type.

# %%
df["grade"] = df["raw_grade"].astype("category")

# %%
df["grade"]
# Out:
# 0    a
# 1    b
# 2    b
# 3    a
# 4    a
# 5    e
# Name: grade, dtype: category
# Categories (3, object): [a, b, e]

# %% [markdown]
# Rename the categories to more meaningful names (assigning to Series.cat.categories is inplace!)

# %%
df["grade"].cat.categories = ["very good", "good", "very bad"]

# %% [markdown]
# Reorder the categories and simultaneously add the missing categories (methods under Series .cat return a new Series per default).

# %%
df["grade"] = df["grade"].cat.set_categories(["very bad", "bad", "medium", "good", "very good"])

# %%
df["grade"]
# Out:
# 0    very good
# 1         good
# 2         good
# 3    very good
# 4    very good
# 5     very bad
# Name: grade, dtype: category
# Categories (5, object): [very bad, bad, medium, good, very good]

# %% [markdown]
# Sorting is per order in the categories, not lexical order.

# %%
df.sort_values(by="grade")
# Out:
#    id raw_grade      grade
# 5   6         e   very bad
# 1   2         b       good
# 2   3         b       good
# 0   1         a  very good
# 3   4         a  very good
# 4   5         a  very good

# %% [markdown]
# Grouping by a categorical column shows also empty categories.

# %%
df.groupby("grade").size()
# Out:
# grade
# very bad     1
# bad          0
# medium       0
# good         2
# very good    3
# dtype: int64

# %% [markdown]
# ## Plotting
# [Plotting](http://pandas.pydata.org/pandas-docs/stable/visualization.html#visualization) docs.

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2000', periods=1000))

# %%
ts = ts.cumsum()

# %%
ts.plot()

# %% [markdown]
# On DataFrame, plot() is a convenience to plot all of the columns with labels:

# %%
df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index,
                  columns=['A', 'B', 'C', 'D'])

# %%
df = df.cumsum()

# %%
plt.figure(); df.plot(); plt.legend(loc='best')

# %% [markdown]
# ## Getting Data In/Out

# %% [markdown]
# ### CSV
# [Writing to a csv file](http://pandas.pydata.org/pandas-docs/stable/io.html#io-store-in-csv)

# %%
df
# Out:
#                    A         B         C         D    F
# 2013-01-01  0.228834  0.828922  0.076657 -0.429588  NaN
# 2013-01-02 -1.318216 -0.712206  0.221339 -0.833141  1.0
# 2013-01-03  0.439934 -1.188770  0.397939 -0.934707  2.0
# 2013-01-04  0.788358 -0.599466 -0.340757 -1.112828  3.0
# 2013-01-05 -0.244217  0.702103 -0.157185 -0.025745  4.0
# 2013-01-06 -1.821725 -0.091525 -0.446694 -0.069316  5.0

# %%
df.to_csv('foo.csv')

# %% [markdown]
# [Reading from a csv file](http://pandas.pydata.org/pandas-docs/stable/io.html#io-read-csv-table)

# %%
pd.read_csv('foo.csv', index_col=0)
# Out:
#                    A         B         C         D    F
# 2013-01-01  0.228834  0.828922  0.076657 -0.429588  NaN
# 2013-01-02 -1.318216 -0.712206  0.221339 -0.833141  1.0
# 2013-01-03  0.439934 -1.188770  0.397939 -0.934707  2.0
# 2013-01-04  0.788358 -0.599466 -0.340757 -1.112828  3.0
# 2013-01-05 -0.244217  0.702103 -0.157185 -0.025745  4.0
# 2013-01-06 -1.821725 -0.091525 -0.446694 -0.069316  5.0

# %% [markdown]
# ### HDF5
# Reading and writing to [HDFStores](http://pandas.pydata.org/pandas-docs/stable/io.html#io-hdf5)
#
# Writing to a HDF5 Store

# %%
df.to_hdf('foo.h5','df')

# %% [markdown]
# Reading from a HDF5 Store

# %%
pd.read_hdf('foo.h5','df')
# Out:
#                     A          B         C          D
# 2000-01-01  -0.067377  -0.035638 -0.021100  -0.752226
# 2000-01-02  -0.341526   0.867899  0.147792  -2.190171
# 2000-01-03  -0.118822   1.501776 -0.472641  -1.448117
# 2000-01-04  -0.727838   0.889072 -2.704155  -2.934499
# 2000-01-05   0.531075   1.073829 -2.847804  -2.517378
# 2000-01-06   0.091479   1.478376 -3.029743  -0.906359
# 2000-01-07   1.492265   2.113159 -3.549888  -2.117010
# 2000-01-08   1.851265   2.703705 -3.141079   0.079449
# 2000-01-09   2.213547   3.685811 -3.029953   1.620792
# 2000-01-10   2.028055   2.034899 -2.115068   3.566303
# 2000-01-11   2.562459   1.562458 -1.266220   3.125902
# 2000-01-12   3.563649   2.535037 -1.609729   1.636481
# 2000-01-13   3.723012   3.932004 -1.801761   3.817881
# 2000-01-14   5.097816   4.143041 -2.183664   2.784085
# 2000-01-15   5.415682   2.042796 -1.186153   3.828601
# 2000-01-16   5.875182   0.968725 -1.122289   3.771920
# ...

# %% [markdown]
# ### Excel
#
# Reading and writing to [MS Excel](http://pandas.pydata.org/pandas-docs/stable/io.html#io-excel)
#
# Writing to an excel file

# %%
df.to_excel('foo.xlsx', sheet_name='Sheet1')

# %% [markdown]
# Reading from an excel file

# %%
pd.read_excel('foo.xlsx', 'Sheet1', index_col=None, na_values=['NA'])
# Out:
#                     A          B         C          D
# 2000-01-01  -0.067377  -0.035638 -0.021100  -0.752226
# 2000-01-02  -0.341526   0.867899  0.147792  -2.190171
# 2000-01-03  -0.118822   1.501776 -0.472641  -1.448117
# 2000-01-04  -0.727838   0.889072 -2.704155  -2.934499
# 2000-01-05   0.531075   1.073829 -2.847804  -2.517378
# 2000-01-06   0.091479   1.478376 -3.029743  -0.906359
# 2000-01-07   1.492265   2.113159 -3.549888  -2.117010
# 2000-01-08   1.851265   2.703705 -3.141079   0.079449
# 2000-01-09   2.213547   3.685811 -3.029953   1.620792
# 2000-01-10   2.028055   2.034899 -2.115068   3.566303
# 2000-01-11   2.562459   1.562458 -1.266220   3.125902
# 2000-01-12   3.563649   2.535037 -1.609729   1.636481
# 2000-01-13   3.723012   3.932004 -1.801761   3.817881
# 2000-01-14   5.097816   4.143041 -2.183664   2.784085
# 2000-01-15   5.415682   2.042796 -1.186153   3.828601
# 2000-01-16   5.875182   0.968725 -1.122289   3.771920
# ...

# %% [markdown]
# ### Gotchas
# If you are trying an operation and you see an exception like:

# %%
if pd.Series([False, True, False]):
    print("I was true")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-140-9cae3ab0f79f> in <module>()
# ----> 1 if pd.Series([False, True, False]):
#       2     print("I was true")
#
# /Users/takenory/.pyenv/versions/anaconda2-4.0.0/lib/python2.7/site-packages/pandas/core/generic.pyc in __nonzero__(self)
#     885         raise ValueError("The truth value of a {0} is ambiguous. "
#     886                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# --> 887                          .format(self.__class__.__name__))
#     888
#     889     __bool__ = __nonzero__
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %% [markdown]
# See [Comparisons](http://pandas.pydata.org/pandas-docs/stable/basics.html#basics-compare) for an explanation and what to do.
#
# See [Gotchas](http://pandas.pydata.org/pandas-docs/stable/gotchas.html#gotchas) as well.

# %% [markdown]
# ## Play with SQlite DB

# %%
import sqlite3
conn = sqlite3.connect('2. MIS532_Project2.db')
#actors, movies, actors_movies

# %%
cursor = conn.cursor()

# create a table named example
for i in cursor.execute('''select * from actors;'''):
    print(i)
# Out:
# ('1', 'Samuel L. Jackson', 'samuelljackson')
# ('2', 'Harrison Ford', 'harrisonford')
# ('3', 'Robert Downey, Jr.', 'robertdowneyjr')
# ('4', 'Tom Hanks', 'tomhanks')
# ('5', 'Morgan Freeman', 'morganfreeman')
# ('6', 'Scarlett Johansson', 'scarlettjohansson')
# ('7', 'Andy Serkis', 'andyserkis')
# ('8', 'Anthony Daniels', 'anthonydaniels')
# ('9', 'Tom Cruise', 'tomcruise')
# ('10', 'Eddie Murphy', 'eddiemurphy')
# ('11', 'Stanley Tucci', 'stanleytucci')
# ('12', 'Idris Elba', 'idriselba')
# ('13', 'Johnny Depp', 'johnnydepp')
# ('14', 'Ian McKellen', 'ianmckellen')
# ('15', 'Bradley Cooper', 'bradleycooper')
# ('16', 'Don Cheadle', 'doncheadle')
# ('17', 'Vin Diesel', 'vindiesel')
# ('18', 'Michael Caine', 'michaelcaine')
# ('19', 'Gary Oldman', 'garyoldman')
# ('20', 'Dwayne Johnson', 'rock')
# ('21', 'Zoe Saldana', 'zoesaldana')
# ('22', 'Stellan Skarsgard', 'stellanskarsgard')
# ('23', 'Robin Williams', 'robinwilliams')
# ('24', 'Woody Harrelson', 'woodyharrelson')
# ...

# %%
actors = pd.read_sql('select * from actors', conn)

# %%
actors = actors.set_index('actor_ID')

# %%
actors
# Out:
#                      actor_name                 rank
# actor_ID
# 1             Samuel L. Jackson       samuelljackson
# 2                 Harrison Ford         harrisonford
# 3            Robert Downey, Jr.       robertdowneyjr
# 4                     Tom Hanks             tomhanks
# 5                Morgan Freeman        morganfreeman
# 6            Scarlett Johansson    scarlettjohansson
# 7                   Andy Serkis           andyserkis
# 8               Anthony Daniels       anthonydaniels
# 9                    Tom Cruise            tomcruise
# 10                 Eddie Murphy          eddiemurphy
# 11                Stanley Tucci         stanleytucci
# 12                   Idris Elba            idriselba
# 13                  Johnny Depp           johnnydepp
# 14                 Ian McKellen          ianmckellen
# 15               Bradley Cooper        bradleycooper
# 16                  Don Cheadle           doncheadle
# ...

# %%
movies = pd.read_sql('select * from movies', conn)
movies
# Out:
#                         movie_ID  \
# 0                      starwars8
# 1          beautyandthebeast2017
# 2                    wonderwoman
# 3                    jumanji2016
# 4                      marvel17a
# 5                  spiderman2017
# 6                             it
# 7                     marvel2017
# 8                  despicableme3
# 9                     dcfilm1117
# 10                 wolverine2017
# 11                      furious8
# 12                     pixar1117
# 13                chrisnolan2017
# 14                    blumhouse2
# 15                         lego2
# 16                      bossbaby
# 17               greatestshowman
# 18                         potc5
# 19                 legendary2016
# 20                         cars3
# 21             planetoftheapes16
# 22                     split2017
# 23                        wonder
# 24                 transformers5
# 25                      girltrip
# 26             fiftyshadesdarker
# ...

# %%
movies = movies.set_index('movie_ID')
movies
# Out:
#                                                                     movie_name  \
# movie_ID
# starwars8                                             Star Wars: The Last Jedi
# beautyandthebeast2017                              Beauty and the Beast (2017)
# wonderwoman                                                       Wonder Woman
# jumanji2016                                     Jumanji: Welcome to the Jungle
# marvel17a                                       Guardians of the Galaxy Vol. 2
# spiderman2017                                           Spider-Man: Homecoming
# it                                                                          It
# marvel2017                                                      Thor: Ragnarok
# despicableme3                                                  Despicable Me 3
# dcfilm1117                                                      Justice League
# wolverine2017                                                            Logan
# ...

# %%
movies.iloc[302]
# Out:
# movie_name          Tom of Finland
# studio                          KL
# MPAARating                 Unrated
# productionBudget
# Genre                        Drama
# domesticRevenue             381610
# foreighRevenue
# Name: tomoffinland, dtype: object

# %%
movies.describe()
# Out:
#                        movie_name studio MPAARating productionBudget  \
# count                         740    740        740              740
# unique                        740    143          9               66
# top     David Lynch: The Art Life     KL    Unrated
# freq                            1     28        364              635
#
#               Genre domesticRevenue foreighRevenue
# count           740             740            740
# unique           49             732            178
# top     Documentary
# freq            174               2            563

# %%
movies.dtypes
# Out:
# movie_name          object
# studio              object
# MPAARating          object
# productionBudget    object
# Genre               object
# domesticRevenue     object
# foreighRevenue      object
# dtype: object

# %%
# tranlate the datatype to float for numeric values
movies.loc[:, 'productionBudget'] = movies.productionBudget.apply(lambda x: np.nan if x=='' else float(x))
movies.loc[:, 'domesticRevenue'] = movies.domesticRevenue.apply(lambda x: np.nan if x=='' else float(x))
movies.loc[:, 'foreighRevenue'] = movies.foreighRevenue.apply(lambda x: np.nan if x=='' else float(x))
movies.dtypes
# Out:
# movie_name           object
# studio               object
# MPAARating           object
# productionBudget    float64
# Genre                object
# domesticRevenue     float64
# foreighRevenue      float64
# dtype: object

# %%
movies.describe()
# Out:
#        productionBudget  domesticRevenue  foreighRevenue
# count      1.050000e+02     7.380000e+02    1.770000e+02
# mean       5.853352e+07     1.704856e+07    1.182360e+08
# std        5.787153e+07     5.988966e+07    1.831090e+08
# min        1.000000e+05     4.220000e+02    1.002100e+05
# 25%        2.000000e+07     2.100100e+04    8.100000e+06
# 50%        3.500000e+07     1.717830e+05    3.545255e+07
# 75%        8.400000e+07     2.534340e+06    1.362000e+08
# max        2.500000e+08     6.593639e+08    1.009997e+09

# %%
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %%
movies.describe()
# Out:
#        productionBudget  domesticRevenue  foreighRevenue
# count           105.000          738.000         177.000
# mean       58533523.810     17048558.369   118235955.277
# std        57871532.576     59889664.749   183108957.165
# min          100000.000          422.000      100210.000
# 25%        20000000.000        21001.000     8100000.000
# 50%        35000000.000       171783.000    35452547.000
# 75%        84000000.000      2534340.500   136200000.000
# max       250000000.000    659363944.000  1009996733.000

# %% [markdown]
# ### Answer the Project 2 Query questions

# %%
# 4.a.1: What is the total Domestic revenue for all the movies in 2017?
movies.domesticRevenue.sum()
# Out:
# 12581836076.0

# %%
# 4.a.2: What is the total foreign revenue?
movies.foreighRevenue.sum()
# Out:
# 20927764084.0

# %%
# 4.b.1: How many movies have available budget information?
movies.productionBudget.notnull().sum()
# Out:
# 105

# %%
# 4.b.1: Among these movies, we assume that movies are considered to be profitable if the gross revenue (domestic plus foreign revenue) is greater than twice the budget. How many movies were profitable in 2017?
movies['profitable'] = np.nan
# this step was wrong
# we only want profitable or not for those movies with Budget information, not all movies
movies['profitable'] = movies.domesticRevenue + movies.foreighRevenue >= 2* (movies.productionBudget)
movies.profitable.value_counts()
# Out:
# False    678
# True      62
# Name: profitable, dtype: int64

# %%
# delete the column and start from scratch
del movies['profitable']

# %%
movies.loc[movies.productionBudget.notnull(), 'profitable'] = (
    (movies.total_revenue>=2*movies.productionBudget).loc[movies.productionBudget.notnull()]
)

# %%
# now we get the correct anwer of 68 instead of 62
movies.profitable.value_counts(dropna=False)
# Out:
# NaN      635
# True      68
# False     37
# Name: profitable, dtype: int64

# %%
# 4.c.1: Which actor (provide full actor name) starred in the most number of movies in 2017? How many movies did he or she star in?
am = pd.read_sql('select * from actors_movies;', conn)
am
# Out:
#                    movie_ID             actor_ID
# 0                 starwars8           markhamill
# 1                 starwars8         carriefisher
# 2                 starwars8           adamdriver
# 3                 starwars8          daisyridley
# 4                 starwars8           johnboyega
# 5                 starwars8           oscarisaac
# 6                 starwars8         lupitanyongo
# 7                 starwars8           andyserkis
# 8                 starwars8      domhnallgleeson
# 9                 starwars8       anthonydaniels
# 10                starwars8            lauradern
# 11                starwars8       beniciodeltoro
# 12                starwars8       kellymarietran
# 13    beautyandthebeast2017           emmawatson
# 14    beautyandthebeast2017            lukeevans
# 15    beautyandthebeast2017         emmathompson
# 16    beautyandthebeast2017           kevinkline
# 17    beautyandthebeast2017           danstevens
# ...

# %%
top_actors = am.groupby('actor_ID').size().sort_values(ascending=False)
top_actors
# Out:
# actor_ID
# danstevens            5
# woodyharrelson        5
# jackiechan            5
# gabrieliglesias       5
# eddieizzard           4
# bradleywhitford       4
# bryancranston         4
# michaelcera           4
# mattdamon             4
# michaelfassbender     4
# idriselba             4
# christopherplummer    4
# samuelljackson        4
# naomiwatts            4
# billpullman           4
# karengillan           3
# susansarandon         3
# katebeckinsale        3
# danedehaan            3
# michaelkeaton         3
# anthonyhopkins        3
# rileykeough           3
# stevecoogan           3
# michaelpena           3
# juliannemoore         3
# judygreer             3
# judidench             3
# lilyjames             3
# thomasmann            3
# joshgad               3
#                      ..
# kiefersutherland      1
# kevinpollak           1
# kevincostner          1
# kerrywashington       1
# kellymarietran        1
# kellymacdonald        1
# kellylynch            1
# ...

# %%
top_actors.index[top_actors==5]
# Out:
# Index(['danstevens', 'woodyharrelson', 'jackiechan', 'gabrieliglesias'], dtype='object', name='actor_ID')

# %%
# 4.c.2: Provide a list of all the movies (movie names) that he or she is featured in.
am.loc[am.actor_ID.isin(top_actors.index[top_actors==5])].sort_values(by='actor_ID')
# Out:
#                        movie_ID         actor_ID
# 17        beautyandthebeast2017       danstevens
# 716                    colossal       danstevens
# 698                  norman2017       danstevens
# 672  themanwhoinventedchristmas       danstevens
# 616                    marshall       danstevens
# 384                     thelamb  gabrieliglesias
# 458                     nutjob2  gabrieliglesias
# 248                   ferdinand  gabrieliglesias
# 103                   pixar1117  gabrieliglesias
# 342                     smurfs3  gabrieliglesias
# 407                theforeigner       jackiechan
# 878                  kungfuyoga       jackiechan
# 461                     nutjob2       jackiechan
# 298                     ninjago       jackiechan
# 909              railroadtigers       jackiechan
# 315             threebillboards   woodyharrelson
# 562              theglasscastle   woodyharrelson
# 157           planetoftheapes16   woodyharrelson
# ...
